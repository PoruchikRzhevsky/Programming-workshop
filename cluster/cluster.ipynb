# %%
#Importing the libraries

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Loading the data

data = pd.read_csv('Terzan 2 VI photometry (Ortolani+ 1997).csv')

# %%
data
# Out:
#       No    Xpos    Ypos    Vmag    V-I
# 0      1  281.22    2.77  21.056  2.310
# 1      2  232.15    6.34  20.389  3.000
# 2      3  729.36    8.91  21.445  3.299
# 3      4  552.54   10.87  20.432  3.771
# 4      5  867.27   13.52  21.919  3.188
# ..   ...     ...     ...     ...    ...
# 716  717  140.54  985.55  20.093  2.858
# 717  718  787.97  987.26  20.539  3.069
# 718  719  417.81  988.00  19.402  1.847
# 719  720  740.95  988.93  19.628  3.543
# 720  721  550.52  991.42  18.830  3.298
#
# [721 rows x 5 columns]

# %%
# Plot the data and the best-fit line

plt.rc("font", size=10)
plt.rcParams["font.family"] = "Times New Roman"
fig, ax = plt.subplots(figsize=(10, 10))

# ax.title.set_fontsize(15)
ax.set_xlabel(r"V-I [mag]")
ax.xaxis.label.set_fontsize(20)
ax.set_ylabel(r"V [mag]")
ax.yaxis.label.set_fontsize(20)
ax.invert_yaxis()
ax.tick_params(axis="both", which="major", length=10, width=0.5, labelsize=15)
ax.tick_params(axis="both", which="minor", length=5, width=0.5, labelsize=15)
# plt.xticks(rotation=45)
plt.tight_layout()  

ax.scatter(data['V-I'], data['Vmag'], color='blue')

plt.show() 

# fig.savefig('CMD.png', bbox_inches='tight')
